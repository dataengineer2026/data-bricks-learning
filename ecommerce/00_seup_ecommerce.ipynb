# %%
# %sql
create catalog ecommerce;
use catalog ecommerce;
create schema if not exists e_comm_bronze;
use schema e_comm_bronze;
create volume if not exists e_comm_source;

# %%
# %sql
use catalog ecommerce;
create schema if not exists e_comm_silver;

# %%
# %sql
use catalog ecommerce;
create schema if not exists e_comm_gold;

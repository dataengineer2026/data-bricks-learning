# %%
# %sql
use catalog ecommerce;
use schema e_comm_bronze;

# %%
df_regions = spark.read.parquet('/Volumes/ecommerce/e_comm_bronze/e_comm_source/Regions.parquet')
df_regions.write.format("delta").mode("overwrite").saveAsTable("tblRegions")

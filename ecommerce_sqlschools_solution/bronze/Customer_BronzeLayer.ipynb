# %%
df1 = spark.read.parquet("/Volumes/projectv1/projectschema/projectsource/CustomersFile1.parquet", header = "true")
display(df1)

# %%
df2 = spark.read.parquet("/Volumes/projectv1/projectschema/projectsource/CustomersFile2.parquet", header = "true")
display(df2)

# %%
import pandas as pd
df3 = pd.concat([df1.toPandas(), df2.toPandas()])
df3

# %%
# %sql
use catalog projectv1

# %%
# %sql
use schema projectschema

# %%
df1.write.format("delta").saveAsTable("tblCustomersSource")
